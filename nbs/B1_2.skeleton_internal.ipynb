# %%
import pickle
import numpy as np

import bbsQt
import bbsQt.model.BBS_pp_utils as bbpp

# %%
skeleton = pickle.load(open("/home/hoseung/Work/Kinect_BBS_demo/G1/000/BT/bodytracking_data.pickle", "rb"))

# %%
# remove preceeding non-detections
while True:
    if len(skeleton[0]) ==0:
        skeleton.pop(0)
    else:
        break
        
# remove trailing non-detections
while True:
    if len(skeleton[-1]) ==0:
        skeleton.pop(-1)
    else:
        break

# %%
skeleton
# Out:
# [[[['PELVIS', 218, 302],
#    ['SPINE_NAVAL', 228, 257],
#    ['SPINE_CHEST', 244, 213],
#    ['NECK', 279, 136],
#    ['CLAVICLE_LEFT', 274, 148],
#    ['SHOULDER_LEFT', 279, 163],
#    ['ELBOW_LEFT', 283, 217],
#    ['WRIST_LEFT', 326, 257],
#    ['HAND_LEFT', 341, 275],
#    ['HANDTIP_LEFT', 351, 299],
#    ['THUMB_LEFT', 345, 289],
#    ['CLAVICLE_RIGHT', 271, 149],
#    ['SHOULDER_RIGHT', 267, 168],
#    ['ELBOW_RIGHT', 306, 329],
#    ['WRIST_RIGHT', 401, 337],
#    ['HAND_RIFHT', 427, 340],
#    ['HANDTIP_RIGHT', 426, 342],
#    ['THUMB_LEFT', 417, 307],
#    ['HIP_LEFT', 228, 287],
#    ['KNEE_LEFT', 260, 357],
#    ['ANKLE_LEFT', 223, 389],
#    ['ROOT_LEFT', 240, 407],
#    ['HIP_RIGHT', 208, 318],
#    ['KNEE_RIGHT', 237, 402],
#    ['ANKLE_RIGHT', 195, 416],
#    ['FOOT_RIGHT', 209, 434],
#    ['HEAD', 298, 109],
#    ['NOSE', 351, 95],
#    ['EYE_LEFT', 331, 90],
#    ['EAR_LEFT', 289, 105],
#    ['EYE_RIGHT', 339, 80],
#    ['EAR_RIGHT', 300, 68]]],
# ...

# %%
n_points = len(skeleton)

# %%
arr = np.zeros(n_points, dtype=bbpp.get_dtypes(skeleton="KINECT"))

# %%
def add_s_in_scene(scene, s, i+1):
    
    scene[s[0]] =

# %%
for i, this_frame in enumerate(skeleton):
    if len(this_frame) > 0:
        for this_person in this_frame:
            if len(this_person) > 0:
                for s in this_person:
                    if len(s) > 0:
                        pass
                        #add_s_in_scene(scene, s, i+1)

# %%
s
# Out:
# ['EAR_RIGHT', 299, 71]

# %%
def get_skeletons(scene, iframe):
    for ss, obj in zip(scene, ll['objects']):
        add_frame_joint(ss['data'], obj['keypoints'], iframe)
        ss['data'][iframe]['frame'] = iframe + 1

# %%
for i, fn in enumerate(fn_frames):
        get_skeletons(scene, ll, this_frame -1)

# %%
# 초기 비는 프레임은 삭제
# 중간에 비는 프레임은.... 몰라 
for sk in skeleton:
    if len(sk) > 0:
# Out:
#   File "/tmp/ipykernel_1086232/560103771.py", line 6
#
#     ^
# IndentationError: expected an indented block
