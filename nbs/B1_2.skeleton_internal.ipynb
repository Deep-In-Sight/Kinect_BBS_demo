# %%
import pickle
import numpy as np

# %%
skeleton = pickle.load(open("/home/hoseung/Work/Kinect_BBS_demo/G1/000/BT/bodytracking_data.pickle", "rb"))

# %%
# remove preceeding non-detections
while True:
    if len(skeleton[0]) ==0:
        skeleton.pop(0)
    else:
        break
        
# remove trailing non-detections
while True:
    if len(skeleton[-1]) ==0:
        skeleton.pop(-1)
    else:
        break

# %%
skeleton
# Out:
# [[[['PELVIS', 206, 318],
#    ['SPINE_NAVAL', 206, 264],
#    ['SPINE_CHEST', 208, 212],
#    ['NECK', 228, 130],
#    ['CLAVICLE_LEFT', 223, 144],
#    ['SHOULDER_LEFT', 223, 161],
#    ['ELBOW_LEFT', 234, 217],
#    ['WRIST_LEFT', 286, 244],
#    ['HAND_LEFT', 306, 252],
#    ['HANDTIP_LEFT', 322, 271],
#    ['THUMB_LEFT', 298, 249],
#    ['CLAVICLE_RIGHT', 225, 142],
#    ['SHOULDER_RIGHT', 231, 154],
#    ['ELBOW_RIGHT', 287, 298],
#    ['WRIST_RIGHT', 372, 308],
#    ['HAND_RIFHT', 401, 311],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 343, 276],
#    ['HIP_LEFT', 204, 303],
#    ['KNEE_LEFT', 243, 367],
#    ['ANKLE_LEFT', 214, 417],
#    ['ROOT_LEFT', 233, 428],
#    ['HIP_RIGHT', 209, 334],
#    ['KNEE_RIGHT', 267, 408],
#    ['ANKLE_RIGHT', 232, 451],
#    ['FOOT_RIGHT', 252, 459],
#    ['HEAD', 241, 103],
#    ['NOSE', 303, 99],
#    ['EYE_LEFT', 289, 88],
#    ['EAR_LEFT', 246, 91],
#    ['EYE_RIGHT', 295, 83],
#    ['EAR_RIGHT', 248, 69]]],
#  [[['PELVIS', 206, 318],
#    ['SPINE_NAVAL', 206, 264],
#    ['SPINE_CHEST', 208, 212],
#    ['NECK', 227, 130],
#    ['CLAVICLE_LEFT', 223, 144],
#    ['SHOULDER_LEFT', 223, 160],
#    ['ELBOW_LEFT', 233, 217],
#    ['WRIST_LEFT', 286, 243],
#    ['HAND_LEFT', 306, 251],
#    ['HANDTIP_LEFT', 322, 270],
#    ['THUMB_LEFT', 298, 249],
#    ['CLAVICLE_RIGHT', 224, 142],
#    ['SHOULDER_RIGHT', 231, 154],
#    ['ELBOW_RIGHT', 288, 299],
#    ['WRIST_RIGHT', 373, 308],
#    ['HAND_RIFHT', 401, 311],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 343, 276],
#    ['HIP_LEFT', 204, 303],
#    ['KNEE_LEFT', 243, 367],
#    ['ANKLE_LEFT', 214, 417],
#    ['ROOT_LEFT', 233, 427],
#    ['HIP_RIGHT', 209, 335],
#    ['KNEE_RIGHT', 267, 408],
#    ['ANKLE_RIGHT', 232, 450],
#    ['FOOT_RIGHT', 252, 459],
#    ['HEAD', 241, 102],
#    ['NOSE', 301, 98],
#    ['EYE_LEFT', 287, 88],
#    ['EAR_LEFT', 244, 94],
#    ['EYE_RIGHT', 293, 82],
#    ['EAR_RIGHT', 249, 67]]],
#  [[['PELVIS', 206, 318],
#    ['SPINE_NAVAL', 206, 264],
#    ['SPINE_CHEST', 208, 212],
#    ['NECK', 227, 130],
#    ['CLAVICLE_LEFT', 223, 144],
#    ['SHOULDER_LEFT', 223, 160],
#    ['ELBOW_LEFT', 233, 217],
#    ['WRIST_LEFT', 286, 243],
#    ['HAND_LEFT', 306, 251],
#    ['HANDTIP_LEFT', 322, 270],
#    ['THUMB_LEFT', 298, 249],
#    ['CLAVICLE_RIGHT', 224, 142],
#    ['SHOULDER_RIGHT', 231, 154],
#    ['ELBOW_RIGHT', 288, 299],
#    ['WRIST_RIGHT', 373, 308],
#    ['HAND_RIFHT', 401, 311],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 343, 276],
#    ['HIP_LEFT', 204, 303],
#    ['KNEE_LEFT', 243, 367],
#    ['ANKLE_LEFT', 214, 417],
#    ['ROOT_LEFT', 233, 427],
#    ['HIP_RIGHT', 209, 335],
#    ['KNEE_RIGHT', 267, 408],
#    ['ANKLE_RIGHT', 232, 450],
#    ['FOOT_RIGHT', 252, 459],
#    ['HEAD', 241, 102],
#    ['NOSE', 301, 98],
#    ['EYE_LEFT', 287, 88],
#    ['EAR_LEFT', 244, 94],
#    ['EYE_RIGHT', 293, 82],
#    ['EAR_RIGHT', 249, 67]]],
#  [[['PELVIS', 206, 318],
#    ['SPINE_NAVAL', 206, 264],
#    ['SPINE_CHEST', 208, 212],
#    ['NECK', 227, 130],
#    ['CLAVICLE_LEFT', 223, 144],
#    ['SHOULDER_LEFT', 223, 160],
#    ['ELBOW_LEFT', 233, 217],
#    ['WRIST_LEFT', 286, 243],
#    ['HAND_LEFT', 306, 251],
#    ['HANDTIP_LEFT', 322, 270],
#    ['THUMB_LEFT', 298, 249],
#    ['CLAVICLE_RIGHT', 224, 142],
#    ['SHOULDER_RIGHT', 231, 154],
#    ['ELBOW_RIGHT', 288, 299],
#    ['WRIST_RIGHT', 373, 308],
#    ['HAND_RIFHT', 401, 311],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 343, 276],
#    ['HIP_LEFT', 204, 303],
#    ['KNEE_LEFT', 243, 367],
#    ['ANKLE_LEFT', 214, 417],
#    ['ROOT_LEFT', 233, 427],
#    ['HIP_RIGHT', 209, 335],
#    ['KNEE_RIGHT', 267, 408],
#    ['ANKLE_RIGHT', 232, 450],
#    ['FOOT_RIGHT', 252, 459],
#    ['HEAD', 241, 102],
#    ['NOSE', 302, 98],
#    ['EYE_LEFT', 287, 88],
#    ['EAR_LEFT', 244, 94],
#    ['EYE_RIGHT', 293, 82],
#    ['EAR_RIGHT', 249, 67]]],
#  [[['PELVIS', 206, 318],
#    ['SPINE_NAVAL', 206, 264],
#    ['SPINE_CHEST', 208, 212],
#    ['NECK', 227, 130],
#    ['CLAVICLE_LEFT', 223, 144],
#    ['SHOULDER_LEFT', 223, 160],
#    ['ELBOW_LEFT', 233, 217],
#    ['WRIST_LEFT', 286, 243],
#    ['HAND_LEFT', 306, 251],
#    ['HANDTIP_LEFT', 322, 270],
#    ['THUMB_LEFT', 298, 249],
#    ['CLAVICLE_RIGHT', 224, 142],
#    ['SHOULDER_RIGHT', 231, 154],
#    ['ELBOW_RIGHT', 288, 299],
#    ['WRIST_RIGHT', 373, 308],
#    ['HAND_RIFHT', 401, 311],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 343, 276],
#    ['HIP_LEFT', 204, 303],
#    ['KNEE_LEFT', 243, 367],
#    ['ANKLE_LEFT', 214, 417],
#    ['ROOT_LEFT', 233, 427],
#    ['HIP_RIGHT', 209, 335],
#    ['KNEE_RIGHT', 267, 408],
#    ['ANKLE_RIGHT', 232, 450],
#    ['FOOT_RIGHT', 252, 459],
#    ['HEAD', 241, 102],
#    ['NOSE', 302, 98],
#    ['EYE_LEFT', 287, 88],
#    ['EAR_LEFT', 244, 94],
#    ['EYE_RIGHT', 293, 82],
#    ['EAR_RIGHT', 249, 67]]],
#  [[['PELVIS', 206, 318],
#    ['SPINE_NAVAL', 206, 264],
#    ['SPINE_CHEST', 208, 212],
#    ['NECK', 227, 130],
#    ['CLAVICLE_LEFT', 223, 144],
#    ['SHOULDER_LEFT', 223, 160],
#    ['ELBOW_LEFT', 233, 217],
#    ['WRIST_LEFT', 286, 243],
#    ['HAND_LEFT', 306, 251],
#    ['HANDTIP_LEFT', 322, 270],
#    ['THUMB_LEFT', 298, 249],
#    ['CLAVICLE_RIGHT', 224, 142],
#    ['SHOULDER_RIGHT', 231, 154],
#    ['ELBOW_RIGHT', 288, 299],
#    ['WRIST_RIGHT', 373, 308],
#    ['HAND_RIFHT', 401, 311],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 343, 276],
#    ['HIP_LEFT', 204, 303],
#    ['KNEE_LEFT', 243, 367],
#    ['ANKLE_LEFT', 214, 417],
#    ['ROOT_LEFT', 233, 427],
#    ['HIP_RIGHT', 209, 335],
#    ['KNEE_RIGHT', 267, 408],
#    ['ANKLE_RIGHT', 232, 450],
#    ['FOOT_RIGHT', 252, 459],
#    ['HEAD', 241, 102],
#    ['NOSE', 302, 98],
#    ['EYE_LEFT', 287, 88],
#    ['EAR_LEFT', 244, 94],
#    ['EYE_RIGHT', 293, 82],
#    ['EAR_RIGHT', 249, 67]]],
#  [[['PELVIS', 205, 317],
#    ['SPINE_NAVAL', 205, 264],
#    ['SPINE_CHEST', 206, 213],
#    ['NECK', 227, 131],
#    ['CLAVICLE_LEFT', 222, 145],
#    ['SHOULDER_LEFT', 223, 160],
#    ['ELBOW_LEFT', 233, 214],
#    ['WRIST_LEFT', 285, 241],
#    ['HAND_LEFT', 304, 250],
#    ['HANDTIP_LEFT', 320, 269],
#    ['THUMB_LEFT', 299, 249],
#    ['CLAVICLE_RIGHT', 224, 144],
#    ['SHOULDER_RIGHT', 231, 159],
#    ['ELBOW_RIGHT', 294, 304],
#    ['WRIST_RIGHT', 377, 307],
#    ['HAND_RIFHT', 402, 312],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 344, 277],
#    ['HIP_LEFT', 203, 301],
#    ['KNEE_LEFT', 243, 364],
#    ['ANKLE_LEFT', 214, 412],
#    ['ROOT_LEFT', 233, 423],
#    ['HIP_RIGHT', 207, 334],
#    ['KNEE_RIGHT', 264, 407],
#    ['ANKLE_RIGHT', 230, 446],
#    ['FOOT_RIGHT', 250, 455],
#    ['HEAD', 241, 102],
#    ['NOSE', 302, 97],
#    ['EYE_LEFT', 287, 88],
#    ['EAR_LEFT', 242, 94],
#    ['EYE_RIGHT', 293, 81],
#    ['EAR_RIGHT', 249, 66]]],
#  [[['PELVIS', 205, 317],
#    ['SPINE_NAVAL', 205, 264],
#    ['SPINE_CHEST', 206, 213],
#    ['NECK', 227, 131],
#    ['CLAVICLE_LEFT', 222, 145],
#    ['SHOULDER_LEFT', 223, 159],
#    ['ELBOW_LEFT', 233, 214],
#    ['WRIST_LEFT', 285, 240],
#    ['HAND_LEFT', 304, 250],
#    ['HANDTIP_LEFT', 320, 269],
#    ['THUMB_LEFT', 299, 249],
#    ['CLAVICLE_RIGHT', 224, 144],
#    ['SHOULDER_RIGHT', 231, 159],
#    ['ELBOW_RIGHT', 295, 305],
#    ['WRIST_RIGHT', 377, 307],
#    ['HAND_RIFHT', 402, 312],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 345, 277],
#    ['HIP_LEFT', 203, 301],
#    ['KNEE_LEFT', 242, 364],
#    ['ANKLE_LEFT', 214, 412],
#    ['ROOT_LEFT', 232, 422],
#    ['HIP_RIGHT', 207, 334],
#    ['KNEE_RIGHT', 263, 406],
#    ['ANKLE_RIGHT', 229, 446],
#    ['FOOT_RIGHT', 249, 454],
#    ['HEAD', 241, 102],
#    ['NOSE', 302, 97],
#    ['EYE_LEFT', 287, 88],
#    ['EAR_LEFT', 242, 94],
#    ['EYE_RIGHT', 293, 81],
#    ['EAR_RIGHT', 249, 66]]],
#  [[['PELVIS', 205, 317],
#    ['SPINE_NAVAL', 205, 264],
#    ['SPINE_CHEST', 206, 213],
#    ['NECK', 227, 131],
#    ['CLAVICLE_LEFT', 222, 145],
#    ['SHOULDER_LEFT', 223, 159],
#    ['ELBOW_LEFT', 233, 214],
#    ['WRIST_LEFT', 285, 240],
#    ['HAND_LEFT', 304, 250],
#    ['HANDTIP_LEFT', 320, 268],
#    ['THUMB_LEFT', 299, 249],
#    ['CLAVICLE_RIGHT', 224, 144],
#    ['SHOULDER_RIGHT', 231, 159],
#    ['ELBOW_RIGHT', 295, 305],
#    ['WRIST_RIGHT', 378, 307],
#    ['HAND_RIFHT', 402, 312],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 345, 277],
#    ['HIP_LEFT', 203, 301],
#    ['KNEE_LEFT', 242, 364],
#    ['ANKLE_LEFT', 214, 411],
#    ['ROOT_LEFT', 232, 422],
#    ['HIP_RIGHT', 207, 334],
#    ['KNEE_RIGHT', 263, 406],
#    ['ANKLE_RIGHT', 229, 446],
#    ['FOOT_RIGHT', 249, 454],
#    ['HEAD', 241, 102],
#    ['NOSE', 302, 97],
#    ['EYE_LEFT', 287, 87],
#    ['EAR_LEFT', 242, 94],
#    ['EYE_RIGHT', 293, 81],
#    ['EAR_RIGHT', 249, 66]]],
#  [[['PELVIS', 205, 317],
#    ['SPINE_NAVAL', 205, 264],
#    ['SPINE_CHEST', 206, 213],
#    ['NECK', 227, 130],
#    ['CLAVICLE_LEFT', 222, 144],
#    ['SHOULDER_LEFT', 222, 159],
#    ['ELBOW_LEFT', 233, 213],
#    ['WRIST_LEFT', 285, 240],
#    ['HAND_LEFT', 304, 249],
#    ['HANDTIP_LEFT', 319, 268],
#    ['THUMB_LEFT', 299, 249],
#    ['CLAVICLE_RIGHT', 223, 143],
#    ['SHOULDER_RIGHT', 232, 160],
#    ['ELBOW_RIGHT', 296, 306],
#    ['WRIST_RIGHT', 378, 308],
#    ['HAND_RIFHT', 402, 312],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 345, 277],
#    ['HIP_LEFT', 203, 301],
#    ['KNEE_LEFT', 242, 363],
#    ['ANKLE_LEFT', 214, 411],
#    ['ROOT_LEFT', 232, 421],
#    ['HIP_RIGHT', 207, 334],
#    ['KNEE_RIGHT', 263, 406],
#    ['ANKLE_RIGHT', 229, 445],
#    ['FOOT_RIGHT', 249, 453],
#    ['HEAD', 241, 102],
#    ['NOSE', 302, 96],
#    ['EYE_LEFT', 286, 86],
#    ['EAR_LEFT', 242, 93],
#    ['EYE_RIGHT', 293, 80],
#    ['EAR_RIGHT', 249, 65]]],
#  [[['PELVIS', 204, 316],
#    ['SPINE_NAVAL', 204, 264],
#    ['SPINE_CHEST', 206, 214],
#    ['NECK', 226, 130],
#    ['CLAVICLE_LEFT', 221, 144],
#    ['SHOULDER_LEFT', 221, 158],
#    ['ELBOW_LEFT', 231, 212],
#    ['WRIST_LEFT', 284, 238],
#    ['HAND_LEFT', 303, 248],
#    ['HANDTIP_LEFT', 318, 267],
#    ['THUMB_LEFT', 299, 249],
#    ['CLAVICLE_RIGHT', 223, 143],
#    ['SHOULDER_RIGHT', 232, 161],
#    ['ELBOW_RIGHT', 299, 308],
#    ['WRIST_RIGHT', 380, 306],
#    ['HAND_RIFHT', 403, 311],
#    ['HANDTIP_RIGHT', 407, 323],
#    ['THUMB_LEFT', 346, 278],
#    ['HIP_LEFT', 203, 300],
#    ['KNEE_LEFT', 243, 361],
#    ['ANKLE_LEFT', 214, 407],
#    ['ROOT_LEFT', 233, 418],
#    ['HIP_RIGHT', 206, 333],
#    ['KNEE_RIGHT', 262, 404],
#    ['ANKLE_RIGHT', 228, 442],
#    ['FOOT_RIGHT', 247, 450],
#    ['HEAD', 240, 101],
#    ['NOSE', 302, 95],
#    ['EYE_LEFT', 286, 86],
#    ['EAR_LEFT', 241, 93],
#    ['EYE_RIGHT', 293, 79],
#    ['EAR_RIGHT', 249, 63]]],
#  [[['PELVIS', 204, 316],
#    ['SPINE_NAVAL', 204, 264],
#    ['SPINE_CHEST', 206, 214],
#    ['NECK', 226, 130],
#    ['CLAVICLE_LEFT', 221, 144],
#    ['SHOULDER_LEFT', 221, 158],
#    ['ELBOW_LEFT', 231, 212],
#    ['WRIST_LEFT', 284, 237],
#    ['HAND_LEFT', 302, 248],
#    ['HANDTIP_LEFT', 318, 267],
#    ['THUMB_LEFT', 298, 248],
#    ['CLAVICLE_RIGHT', 223, 143],
#    ['SHOULDER_RIGHT', 231, 161],
#    ['ELBOW_RIGHT', 300, 308],
#    ['WRIST_RIGHT', 381, 306],
#    ['HAND_RIFHT', 404, 310],
#    ['HANDTIP_RIGHT', 407, 322],
#    ['THUMB_LEFT', 346, 277],
#    ['HIP_LEFT', 203, 300],
#    ['KNEE_LEFT', 243, 360],
#    ['ANKLE_LEFT', 215, 407],
#    ['ROOT_LEFT', 233, 417],
#    ['HIP_RIGHT', 206, 333],
#    ['KNEE_RIGHT', 262, 404],
#    ['ANKLE_RIGHT', 227, 442],
#    ['FOOT_RIGHT', 247, 450],
#    ['HEAD', 239, 101],
#    ['NOSE', 301, 94],
#    ['EYE_LEFT', 286, 85],
#    ['EAR_LEFT', 241, 92],
#    ['EYE_RIGHT', 293, 78],
#    ['EAR_RIGHT', 248, 64]]],
#  [[['PELVIS', 204, 316],
#    ['SPINE_NAVAL', 204, 264],
#    ['SPINE_CHEST', 206, 214],
#    ['NECK', 226, 130],
#    ['CLAVICLE_LEFT', 221, 144],
#    ['SHOULDER_LEFT', 221, 158],
#    ['ELBOW_LEFT', 231, 212],
#    ['WRIST_LEFT', 284, 237],
#    ['HAND_LEFT', 302, 248],
#    ['HANDTIP_LEFT', 318, 267],
#    ['THUMB_LEFT', 298, 248],
#    ['CLAVICLE_RIGHT', 223, 143],
#    ['SHOULDER_RIGHT', 231, 161],
#    ['ELBOW_RIGHT', 300, 308],
#    ['WRIST_RIGHT', 381, 306],
#    ['HAND_RIFHT', 404, 310],
#    ['HANDTIP_RIGHT', 407, 322],
#    ['THUMB_LEFT', 346, 277],
#    ['HIP_LEFT', 203, 300],
#    ['KNEE_LEFT', 243, 360],
#    ['ANKLE_LEFT', 215, 407],
#    ['ROOT_LEFT', 233, 417],
#    ['HIP_RIGHT', 206, 333],
#    ['KNEE_RIGHT', 262, 404],
#    ['ANKLE_RIGHT', 227, 442],
#    ['FOOT_RIGHT', 247, 450],
#    ['HEAD', 239, 101],
#    ['NOSE', 301, 94],
#    ['EYE_LEFT', 286, 85],
#    ['EAR_LEFT', 241, 92],
#    ['EYE_RIGHT', 293, 78],
#    ['EAR_RIGHT', 248, 64]]],
#  [[['PELVIS', 204, 316],
#    ['SPINE_NAVAL', 204, 264],
#    ['SPINE_CHEST', 205, 214],
#    ['NECK', 222, 128],
#    ['CLAVICLE_LEFT', 218, 142],
#    ['SHOULDER_LEFT', 217, 156],
#    ['ELBOW_LEFT', 228, 210],
#    ['WRIST_LEFT', 282, 234],
#    ['HAND_LEFT', 300, 247],
#    ['HANDTIP_LEFT', 316, 265],
#    ['THUMB_LEFT', 298, 248],
#    ['CLAVICLE_RIGHT', 220, 142],
#    ['SHOULDER_RIGHT', 230, 161],
#    ['ELBOW_RIGHT', 305, 308],
#    ['WRIST_RIGHT', 384, 303],
#    ['HAND_RIFHT', 405, 309],
#    ['HANDTIP_RIGHT', 408, 323],
#    ['THUMB_LEFT', 347, 277],
#    ['HIP_LEFT', 203, 299],
#    ['KNEE_LEFT', 243, 359],
#    ['ANKLE_LEFT', 216, 405],
#    ['ROOT_LEFT', 235, 415],
#    ['HIP_RIGHT', 207, 333],
#    ['KNEE_RIGHT', 260, 403],
#    ['ANKLE_RIGHT', 227, 440],
#    ['FOOT_RIGHT', 246, 448],
#    ['HEAD', 236, 99],
#    ['NOSE', 299, 92],
#    ['EYE_LEFT', 282, 83],
#    ['EAR_LEFT', 237, 91],
#    ['EYE_RIGHT', 290, 76],
#    ['EAR_RIGHT', 244, 60]]],
#  [[['PELVIS', 205, 313],
#    ['SPINE_NAVAL', 203, 264],
#    ['SPINE_CHEST', 204, 214],
#    ['NECK', 218, 128],
#    ['CLAVICLE_LEFT', 214, 142],
#    ['SHOULDER_LEFT', 215, 154],
#    ['ELBOW_LEFT', 227, 208],
#    ['WRIST_LEFT', 281, 231],
#    ['HAND_LEFT', 298, 244],
#    ['HANDTIP_LEFT', 313, 262],
#    ['THUMB_LEFT', 298, 248],
#    ['CLAVICLE_RIGHT', 216, 143],
#    ['SHOULDER_RIGHT', 226, 164],
#    ['ELBOW_RIGHT', 304, 311],
#    ['WRIST_RIGHT', 398, 300],
#    ['HAND_RIFHT', 405, 310],
#    ['HANDTIP_RIGHT', 408, 320],
#    ['THUMB_LEFT', 354, 281],
#    ['HIP_LEFT', 203, 296],
#    ['KNEE_LEFT', 240, 355],
#    ['ANKLE_LEFT', 215, 399],
#    ['ROOT_LEFT', 234, 408],
#    ['HIP_RIGHT', 206, 331],
#    ['KNEE_RIGHT', 254, 400],
#    ['ANKLE_RIGHT', 224, 435],
#    ['FOOT_RIGHT', 244, 442],
#    ['HEAD', 231, 97],
#    ['NOSE', 293, 93],
#    ['EYE_LEFT', 276, 85],
#    ['EAR_LEFT', 230, 94],
#    ['EYE_RIGHT', 284, 76],
#    ['EAR_RIGHT', 241, 57]]],
#  [[['PELVIS', 205, 313],
#    ['SPINE_NAVAL', 203, 264],
#    ['SPINE_CHEST', 204, 215],
#    ['NECK', 218, 128],
#    ['CLAVICLE_LEFT', 214, 142],
#    ['SHOULDER_LEFT', 213, 154],
#    ['ELBOW_LEFT', 225, 208],
#    ['WRIST_LEFT', 279, 230],
#    ['HAND_LEFT', 297, 243],
#    ['HANDTIP_LEFT', 312, 261],
#    ['THUMB_LEFT', 298, 248],
#    ['CLAVICLE_RIGHT', 216, 143],
#    ['SHOULDER_RIGHT', 227, 165],
#    ['ELBOW_RIGHT', 305, 312],
#    ['WRIST_RIGHT', 390, 296],
#    ['HAND_RIFHT', 403, 308],
#    ['HANDTIP_RIGHT', 408, 321],
#    ['THUMB_LEFT', 348, 279],
#    ['HIP_LEFT', 203, 296],
#    ['KNEE_LEFT', 240, 353],
#    ['ANKLE_LEFT', 215, 397],
#    ['ROOT_LEFT', 235, 406],
#    ['HIP_RIGHT', 206, 331],
#    ['KNEE_RIGHT', 253, 399],
#    ['ANKLE_RIGHT', 223, 433],
#    ['FOOT_RIGHT', 243, 441],
#    ['HEAD', 230, 97],
#    ['NOSE', 292, 94],
#    ['EYE_LEFT', 276, 86],
#    ['EAR_LEFT', 229, 94],
#    ['EYE_RIGHT', 284, 77],
#    ['EAR_RIGHT', 241, 57]]],
#  [[['PELVIS', 204, 313],
#    ['SPINE_NAVAL', 202, 264],
#    ['SPINE_CHEST', 202, 214],
#    ['NECK', 215, 127],
#    ['CLAVICLE_LEFT', 211, 141],
#    ['SHOULDER_LEFT', 211, 153],
#    ['ELBOW_LEFT', 224, 207],
#    ['WRIST_LEFT', 278, 228],
#    ['HAND_LEFT', 296, 242],
#    ['HANDTIP_LEFT', 311, 260],
#    ['THUMB_LEFT', 298, 248],
#    ['CLAVICLE_RIGHT', 214, 142],
#    ['SHOULDER_RIGHT', 226, 165],
#    ['ELBOW_RIGHT', 307, 311],
#    ['WRIST_RIGHT', 387, 293],
#    ['HAND_RIFHT', 401, 307],
#    ['HANDTIP_RIGHT', 408, 322],
#    ['THUMB_LEFT', 344, 278],
#    ['HIP_LEFT', 202, 295],
#    ['KNEE_LEFT', 239, 352],
#    ['ANKLE_LEFT', 216, 396],
#    ['ROOT_LEFT', 235, 404],
#    ['HIP_RIGHT', 206, 331],
#    ['KNEE_RIGHT', 252, 398],
#    ['ANKLE_RIGHT', 222, 432],
#    ['FOOT_RIGHT', 242, 439],
#    ['HEAD', 227, 95],
#    ['NOSE', 290, 94],
#    ['EYE_LEFT', 274, 86],
#    ['EAR_LEFT', 227, 94],
#    ['EYE_RIGHT', 282, 77],
#    ['EAR_RIGHT', 240, 55]]],
#  [[['PELVIS', 203, 313],
#    ['SPINE_NAVAL', 201, 263],
#    ['SPINE_CHEST', 201, 214],
#    ['NECK', 212, 128],
#    ['CLAVICLE_LEFT', 208, 142],
#    ['SHOULDER_LEFT', 207, 154],
#    ['ELBOW_LEFT', 221, 206],
#    ['WRIST_LEFT', 276, 225],
#    ['HAND_LEFT', 293, 240],
#    ['HANDTIP_LEFT', 308, 257],
#    ['THUMB_LEFT', 296, 246],
#    ['CLAVICLE_RIGHT', 211, 143],
#    ['SHOULDER_RIGHT', 223, 165],
#    ['ELBOW_RIGHT', 307, 307],
#    ['WRIST_RIGHT', 400, 287],
#    ['HAND_RIFHT', 440, 310],
#    ['HANDTIP_RIGHT', 419, 314],
#    ['THUMB_LEFT', 417, 293],
#    ['HIP_LEFT', 201, 295],
#    ['KNEE_LEFT', 236, 352],
#    ['ANKLE_LEFT', 214, 396],
#    ['ROOT_LEFT', 234, 403],
#    ['HIP_RIGHT', 206, 331],
#    ['KNEE_RIGHT', 250, 397],
#    ['ANKLE_RIGHT', 222, 432],
#    ['FOOT_RIGHT', 242, 438],
#    ['HEAD', 223, 96],
#    ['NOSE', 286, 95],
#    ['EYE_LEFT', 270, 87],
#    ['EAR_LEFT', 224, 94],
#    ['EYE_RIGHT', 279, 78],
#    ['EAR_RIGHT', 235, 56]]],
#  [[['PELVIS', 203, 313],
#    ['SPINE_NAVAL', 201, 264],
#    ['SPINE_CHEST', 201, 214],
#    ['NECK', 211, 128],
#    ['CLAVICLE_LEFT', 208, 142],
#    ['SHOULDER_LEFT', 207, 154],
#    ['ELBOW_LEFT', 221, 206],
#    ['WRIST_LEFT', 276, 225],
#    ['HAND_LEFT', 293, 239],
#    ['HANDTIP_LEFT', 308, 257],
#    ['THUMB_LEFT', 296, 246],
#    ['CLAVICLE_RIGHT', 210, 143],
#    ['SHOULDER_RIGHT', 223, 165],
#    ['ELBOW_RIGHT', 307, 307],
#    ['WRIST_RIGHT', 400, 287],
#    ['HAND_RIFHT', 441, 305],
#    ['HANDTIP_RIGHT', 425, 315],
#    ['THUMB_LEFT', 424, 296],
#    ['HIP_LEFT', 201, 295],
#    ['KNEE_LEFT', 236, 352],
#    ['ANKLE_LEFT', 214, 396],
#    ['ROOT_LEFT', 234, 403],
#    ['HIP_RIGHT', 206, 331],
#    ['KNEE_RIGHT', 250, 397],
#    ['ANKLE_RIGHT', 222, 432],
#    ['FOOT_RIGHT', 242, 438],
#    ['HEAD', 222, 96],
#    ['NOSE', 286, 95],
#    ['EYE_LEFT', 270, 87],
#    ['EAR_LEFT', 224, 94],
#    ['EYE_RIGHT', 278, 78],
#    ['EAR_RIGHT', 235, 56]]],
#  [[['PELVIS', 200, 313],
#    ['SPINE_NAVAL', 198, 264],
#    ['SPINE_CHEST', 198, 214],
#    ['NECK', 207, 127],
#    ['CLAVICLE_LEFT', 203, 141],
#    ['SHOULDER_LEFT', 203, 154],
#    ['ELBOW_LEFT', 219, 206],
#    ['WRIST_LEFT', 274, 224],
#    ['HAND_LEFT', 291, 238],
#    ['HANDTIP_LEFT', 307, 255],
#    ['THUMB_LEFT', 295, 245],
#    ['CLAVICLE_RIGHT', 206, 142],
#    ['SHOULDER_RIGHT', 220, 165],
#    ['ELBOW_RIGHT', 308, 305],
#    ['WRIST_RIGHT', 406, 288],
#    ['HAND_RIFHT', 448, 308],
#    ['HANDTIP_RIGHT', 426, 314],
#    ['THUMB_LEFT', 424, 296],
#    ['HIP_LEFT', 198, 296],
#    ['KNEE_LEFT', 231, 353],
#    ['ANKLE_LEFT', 210, 398],
#    ['ROOT_LEFT', 231, 403],
#    ['HIP_RIGHT', 204, 332],
#    ['KNEE_RIGHT', 247, 398],
#    ['ANKLE_RIGHT', 221, 434],
#    ['FOOT_RIGHT', 242, 439],
#    ['HEAD', 217, 96],
#    ['NOSE', 282, 97],
#    ['EYE_LEFT', 267, 88],
#    ['EAR_LEFT', 220, 94],
#    ['EYE_RIGHT', 275, 79],
#    ['EAR_RIGHT', 231, 56]]],
#  [[['PELVIS', 199, 314],
#    ['SPINE_NAVAL', 197, 264],
#    ['SPINE_CHEST', 197, 214],
#    ['NECK', 207, 128],
#    ['CLAVICLE_LEFT', 203, 142],
#    ['SHOULDER_LEFT', 203, 154],
#    ['ELBOW_LEFT', 219, 207],
#    ['WRIST_LEFT', 273, 225],
#    ['HAND_LEFT', 291, 238],
#    ['HANDTIP_LEFT', 307, 256],
#    ['THUMB_LEFT', 295, 245],
#    ['CLAVICLE_RIGHT', 206, 143],
#    ['SHOULDER_RIGHT', 218, 165],
#    ['ELBOW_RIGHT', 308, 303],
#    ['WRIST_RIGHT', 409, 287],
#    ['HAND_RIFHT', 450, 309],
#    ['HANDTIP_RIGHT', 426, 313],
#    ['THUMB_LEFT', 424, 295],
#    ['HIP_LEFT', 197, 297],
#    ['KNEE_LEFT', 229, 354],
#    ['ANKLE_LEFT', 208, 399],
#    ['ROOT_LEFT', 229, 405],
#    ['HIP_RIGHT', 203, 332],
#    ['KNEE_RIGHT', 246, 399],
#    ['ANKLE_RIGHT', 221, 434],
#    ['FOOT_RIGHT', 242, 440],
#    ['HEAD', 218, 96],
#    ['NOSE', 281, 83],
#    ['EYE_LEFT', 263, 75],
#    ['EAR_LEFT', 218, 88],
#    ['EYE_RIGHT', 270, 67],
#    ['EAR_RIGHT', 222, 57]]],
#  [[['PELVIS', 198, 314],
#    ['SPINE_NAVAL', 196, 264],
#    ['SPINE_CHEST', 196, 214],
#    ['NECK', 207, 127],
#    ['CLAVICLE_LEFT', 202, 141],
#    ['SHOULDER_LEFT', 201, 154],
#    ['ELBOW_LEFT', 215, 206],
#    ['WRIST_LEFT', 269, 225],
#    ['HAND_LEFT', 288, 237],
#    ['HANDTIP_LEFT', 306, 254],
#    ['THUMB_LEFT', 294, 244],
#    ['CLAVICLE_RIGHT', 206, 142],
#    ['SHOULDER_RIGHT', 221, 163],
#    ['ELBOW_RIGHT', 310, 302],
#    ['WRIST_RIGHT', 386, 287],
#    ['HAND_RIFHT', 429, 289],
#    ['HANDTIP_RIGHT', 423, 315],
#    ['THUMB_LEFT', 425, 295],
#    ['HIP_LEFT', 195, 297],
#    ['KNEE_LEFT', 230, 354],
#    ['ANKLE_LEFT', 209, 400],
#    ['ROOT_LEFT', 229, 407],
#    ['HIP_RIGHT', 202, 332],
#    ['KNEE_RIGHT', 248, 398],
#    ['ANKLE_RIGHT', 220, 434],
#    ['FOOT_RIGHT', 241, 440],
#    ['HEAD', 218, 96],
#    ['NOSE', 279, 79],
#    ['EYE_LEFT', 260, 73],
#    ['EAR_LEFT', 216, 89],
#    ['EYE_RIGHT', 267, 64],
#    ['EAR_RIGHT', 219, 57]]],
#  [[['PELVIS', 196, 315],
#    ['SPINE_NAVAL', 194, 264],
#    ['SPINE_CHEST', 194, 214],
#    ['NECK', 204, 126],
#    ['CLAVICLE_LEFT', 200, 140],
#    ['SHOULDER_LEFT', 197, 153],
#    ['ELBOW_LEFT', 211, 205],
#    ['WRIST_LEFT', 267, 223],
#    ['HAND_LEFT', 286, 236],
#    ['HANDTIP_LEFT', 304, 252],
#    ['THUMB_LEFT', 291, 242],
#    ['CLAVICLE_RIGHT', 204, 141],
#    ['SHOULDER_RIGHT', 219, 161],
#    ['ELBOW_RIGHT', 309, 301],
#    ['WRIST_RIGHT', 391, 283],
#    ['HAND_RIFHT', 435, 291],
#    ['HANDTIP_RIGHT', 424, 313],
#    ['THUMB_LEFT', 425, 296],
#    ['HIP_LEFT', 191, 298],
#    ['KNEE_LEFT', 226, 356],
#    ['ANKLE_LEFT', 205, 403],
#    ['ROOT_LEFT', 226, 408],
#    ['HIP_RIGHT', 201, 333],
#    ['KNEE_RIGHT', 247, 398],
#    ['ANKLE_RIGHT', 221, 437],
#    ['FOOT_RIGHT', 241, 441],
#    ['HEAD', 215, 94],
#    ['NOSE', 278, 80],
#    ['EYE_LEFT', 260, 73],
#    ['EAR_LEFT', 215, 87],
#    ['EYE_RIGHT', 266, 64],
#    ['EAR_RIGHT', 218, 55]]],
#  [[['PELVIS', 197, 317],
#    ['SPINE_NAVAL', 195, 265],
#    ['SPINE_CHEST', 194, 214],
#    ['NECK', 202, 126],
#    ['CLAVICLE_LEFT', 198, 140],
#    ['SHOULDER_LEFT', 195, 153],
#    ['ELBOW_LEFT', 210, 206],
#    ['WRIST_LEFT', 266, 222],
#    ['HAND_LEFT', 285, 237],
#    ['HANDTIP_LEFT', 305, 252],
#    ['THUMB_LEFT', 290, 241],
#    ['CLAVICLE_RIGHT', 202, 141],
#    ['SHOULDER_RIGHT', 218, 162],
#    ['ELBOW_RIGHT', 310, 301],
#    ['WRIST_RIGHT', 396, 285],
#    ['HAND_RIFHT', 440, 292],
#    ['HANDTIP_RIGHT', 425, 312],
#    ['THUMB_LEFT', 427, 297],
#    ['HIP_LEFT', 192, 301],
#    ['KNEE_LEFT', 225, 359],
#    ['ANKLE_LEFT', 204, 406],
#    ['ROOT_LEFT', 224, 412],
#    ['HIP_RIGHT', 203, 335],
#    ['KNEE_RIGHT', 247, 401],
#    ['ANKLE_RIGHT', 223, 440],
#    ['FOOT_RIGHT', 244, 443],
#    ['HEAD', 212, 94],
#    ['NOSE', 277, 81],
#    ['EYE_LEFT', 260, 73],
#    ['EAR_LEFT', 214, 86],
#    ['EYE_RIGHT', 266, 65],
#    ['EAR_RIGHT', 216, 54]]],
#  [[['PELVIS', 197, 317],
#    ['SPINE_NAVAL', 195, 265],
#    ['SPINE_CHEST', 195, 214],
#    ['NECK', 202, 126],
#    ['CLAVICLE_LEFT', 198, 140],
#    ['SHOULDER_LEFT', 195, 153],
#    ['ELBOW_LEFT', 210, 206],
#    ['WRIST_LEFT', 265, 222],
#    ['HAND_LEFT', 284, 237],
#    ['HANDTIP_LEFT', 304, 252],
#    ['THUMB_LEFT', 289, 241],
#    ['CLAVICLE_RIGHT', 202, 141],
#    ['SHOULDER_RIGHT', 218, 162],
#    ['ELBOW_RIGHT', 310, 301],
#    ['WRIST_RIGHT', 395, 284],
#    ['HAND_RIFHT', 439, 291],
#    ['HANDTIP_RIGHT', 424, 311],
#    ['THUMB_LEFT', 426, 296],
#    ['HIP_LEFT', 192, 301],
#    ['KNEE_LEFT', 225, 359],
#    ['ANKLE_LEFT', 204, 406],
#    ['ROOT_LEFT', 224, 412],
#    ['HIP_RIGHT', 203, 335],
#    ['KNEE_RIGHT', 247, 401],
#    ['ANKLE_RIGHT', 223, 440],
#    ['FOOT_RIGHT', 244, 443],
#    ['HEAD', 212, 94],
#    ['NOSE', 277, 81],
#    ['EYE_LEFT', 260, 73],
#    ['EAR_LEFT', 214, 86],
#    ['EYE_RIGHT', 266, 65],
#    ['EAR_RIGHT', 216, 55]]],
#  [[['PELVIS', 198, 323],
#    ['SPINE_NAVAL', 195, 268],
#    ['SPINE_CHEST', 195, 215],
#    ['NECK', 200, 128],
#    ['CLAVICLE_LEFT', 196, 142],
#    ['SHOULDER_LEFT', 190, 154],
#    ['ELBOW_LEFT', 206, 204],
#    ['WRIST_LEFT', 262, 220],
#    ['HAND_LEFT', 281, 234],
#    ['HANDTIP_LEFT', 302, 250],
#    ['THUMB_LEFT', 283, 234],
#    ['CLAVICLE_RIGHT', 201, 143],
#    ['SHOULDER_RIGHT', 218, 162],
#    ['ELBOW_RIGHT', 311, 298],
#    ['WRIST_RIGHT', 384, 285],
#    ['HAND_RIFHT', 428, 283],
#    ['HANDTIP_RIGHT', 423, 311],
#    ['THUMB_LEFT', 426, 296],
#    ['HIP_LEFT', 192, 307],
#    ['KNEE_LEFT', 227, 366],
#    ['ANKLE_LEFT', 204, 416],
#    ['ROOT_LEFT', 223, 421],
#    ['HIP_RIGHT', 205, 339],
#    ['KNEE_RIGHT', 253, 403],
#    ['ANKLE_RIGHT', 230, 445],
#    ['FOOT_RIGHT', 252, 448],
#    ['HEAD', 209, 96],
#    ['NOSE', 272, 85],
#    ['EYE_LEFT', 256, 74],
#    ['EAR_LEFT', 208, 81],
#    ['EYE_RIGHT', 264, 70],
#    ['EAR_RIGHT', 219, 61]]],
#  [[['PELVIS', 198, 326],
#    ['SPINE_NAVAL', 195, 270],
#    ['SPINE_CHEST', 197, 217],
#    ['NECK', 203, 132],
#    ['CLAVICLE_LEFT', 199, 146],
#    ['SHOULDER_LEFT', 195, 157],
#    ['ELBOW_LEFT', 209, 204],
#    ['WRIST_LEFT', 264, 219],
#    ['HAND_LEFT', 281, 235],
#    ['HANDTIP_LEFT', 302, 250],
#    ['THUMB_LEFT', 283, 234],
#    ['CLAVICLE_RIGHT', 204, 146],
#    ['SHOULDER_RIGHT', 218, 165],
#    ['ELBOW_RIGHT', 298, 302],
#    ['WRIST_RIGHT', 408, 289],
#    ['HAND_RIFHT', 450, 284],
#    ['HANDTIP_RIGHT', 423, 307],
#    ['THUMB_LEFT', 416, 298],
#    ['HIP_LEFT', 192, 312],
#    ['KNEE_LEFT', 224, 374],
#    ['ANKLE_LEFT', 199, 424],
#    ['ROOT_LEFT', 220, 429],
#    ['HIP_RIGHT', 204, 341],
#    ['KNEE_RIGHT', 252, 409],
#    ['ANKLE_RIGHT', 233, 452],
#    ['FOOT_RIGHT', 256, 452],
#    ['HEAD', 211, 101],
#    ['NOSE', 265, 77],
#    ['EYE_LEFT', 246, 73],
#    ['EAR_LEFT', 206, 94],
#    ['EYE_RIGHT', 252, 64],
#    ['EAR_RIGHT', 209, 63]]],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [[['PELVIS', 239, 318],
#    ['SPINE_NAVAL', 253, 268],
#    ['SPINE_CHEST', 262, 218],
#    ['NECK', 285, 125],
#    ['CLAVICLE_LEFT', 271, 138],
#    ['SHOULDER_LEFT', 239, 146],
#    ['ELBOW_LEFT', 202, 195],
#    ['WRIST_LEFT', 254, 215],
#    ['HAND_LEFT', 264, 221],
#    ['HANDTIP_LEFT', 277, 231],
#    ['THUMB_LEFT', 277, 228],
#    ['CLAVICLE_RIGHT', 290, 144],
#    ['SHOULDER_RIGHT', 328, 174],
#    ['ELBOW_RIGHT', 322, 356],
#    ['WRIST_RIGHT', 377, 321],
#    ['HAND_RIFHT', 386, 327],
#    ['HANDTIP_RIGHT', 385, 329],
#    ['THUMB_LEFT', 382, 303],
#    ['HIP_LEFT', 223, 299],
#    ['KNEE_LEFT', 223, 357],
#    ['ANKLE_LEFT', 197, 404],
#    ['ROOT_LEFT', 213, 405],
#    ['HIP_RIGHT', 256, 336],
#    ['KNEE_RIGHT', 255, 389],
#    ['ANKLE_RIGHT', 222, 429],
#    ['FOOT_RIGHT', 236, 429],
#    ['HEAD', 298, 92],
#    ['NOSE', 365, 103],
#    ['EYE_LEFT', 350, 89],
#    ['EAR_LEFT', 298, 84],
#    ['EYE_RIGHT', 361, 84],
#    ['EAR_RIGHT', 318, 54]]]]

# %%
import model.BBS_pp_utils as bbpp

dtype = bbpp.get_dtypes(skeleton="KINECT")
n_points = len(skeleton)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1093946/4148579286.py in <module>
# ----> 1 import model.BBS_pp_utils as bbpp
#       2
#       3 dtype = bbpp.get_dtypes(skeleton="KINECT")
#       4 n_points = len(skeleton)
#
# ModuleNotFoundError: No module named 'model'

# %%
arr = np.zeros(n_points, dtype=)

# %%
n_points
# Out:
# 181

# %%
# 초기 비는 프레임은 삭제
# 중간에 비는 프레임은.... 몰라 
for sk in skeleton:
    if len(sk) > 0:
# Out:
#   File "/tmp/ipykernel_1086232/560103771.py", line 6
#
#     ^
# IndentationError: expected an indented block
